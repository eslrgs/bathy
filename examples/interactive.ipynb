# %% [markdown]
# # Interactive profile drawing
#
# Draw and edit bathymetric profiles by clicking directly on the map.
#
# **Requirements:** install the notebook extras with `uv pip install -e ".[notebook]"`
#
# **Note:** this example requires a live Jupyter session — it will not render
# in the static documentation.

# %%
# %matplotlib widget
import bathy

# %% [markdown]
# ## Load data
#
# Load bathymetry from a local file or fetch a region from GEBCO.

# %%
# data = bathy.load_bathymetry("path/to/your/data.nc")
data = bathy.load_gebco_opendap(
    lon_range=(-12.08, -5.23),
    lat_range=(46.05, 49.54),
    save_path="../data/ne_atlantic_gebco.nc",
)

# %% [markdown]
# ## Draw profiles
#
# Call `draw_profile` to display the bathymetry map.
#
# **Drawing:**
# - **Left-click** to add waypoints along a profile path
# - **Right-click** to finish the current profile and start a new one
# - **Double-click** to stop drawing entirely
#
# **Editing:**
# - **Drag** any waypoint to reposition it (works on finished profiles too)
# - **Middle-click** or press **z** to undo the last placed waypoint
# - **Shift-click** on a waypoint to delete it
# - **Click on a line segment** to insert a new waypoint between two existing ones
#
# The profile plot on the right updates as you draw and edit.

# %%
result = bathy.draw_profile(data)

# %% [markdown]
# ## Access the profiles
#
# After drawing, extracted profiles are available in `result["profiles"]`.

# %%
# All profiles
result["profiles"]

# First profile
profile = result["profiles"][0]
profile

# %% [markdown]
# ## Use with other functions
#
# The drawn profiles work with all existing profile analysis and plotting
# functions.

# %%
bathy.plot_profile(profile)

# %%
# Profile statistics
bathy.profile_stats(profile)

# %%
# Detect knickpoints
bathy.plot_knickpoints(profile)

# %%
# Export to GeoDataFrame
gdf = bathy.to_gdf(profile)
gdf

# %%
# Plot all drawn profiles together
bathy.plot_profiles(result["profiles"])

# %% [markdown]
# ## Save and reload
#
# Save profiles to a file, then reload them for further editing in a later
# session.

# %%
# Save to file
bathy.to_gdf(result["profiles"]).to_file("../data/profiles.gpkg")

# Reload for further editing
reloaded = bathy.profiles_from_file(data, "../data/profiles.gpkg")
result = bathy.draw_profile(data, profiles=reloaded)
